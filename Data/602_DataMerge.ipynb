# %%
import pandas as pd

# %%
# merging two csv files
raw_df = pd.concat(
    map(pd.read_csv, ['https://raw.githubusercontent.com/joannechoi/DC-Crime-Analysis/main/Data/Raw/Crime_Incidents_in_2019.csv',
                      'https://raw.githubusercontent.com/joannechoi/DC-Crime-Analysis/main/Data/Raw/Crime_Incidents_in_2020.csv', 
                      'https://raw.githubusercontent.com/joannechoi/DC-Crime-Analysis/main/Data/Raw/Crime_Incidents_in_2021.csv']), 
                   ignore_index=True)
raw_df
# Out:
#                X          Y  ...  OBJECTID OCTO_RECORD_ID
# 0     -76.982936  38.887601  ...  59514164            NaN
# 1     -77.030789  38.918120  ...  59729089            NaN
# 2     -77.047758  38.897362  ...  59729090            NaN
# 3     -77.028082  38.914841  ...  59729091            NaN
# 4     -77.024586  38.938156  ...  59729092            NaN
# ...          ...        ...  ...       ...            ...
# 84192 -76.975957  38.913030  ...  59507639            NaN
# 84193 -76.967096  38.874618  ...  59507640            NaN
# 84194 -76.991694  38.951346  ...  59507641            NaN
# 84195 -76.982315  38.852411  ...  59507642            NaN
# 84196 -76.962046  38.882849  ...  59507643            NaN
#
# [84197 rows x 25 columns]
